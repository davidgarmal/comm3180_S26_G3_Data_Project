# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import camelot
import calendar
import re
import matplotlib.pyplot as plt

# %%
tuition_df = pd.read_csv('tuition_cleaned.csv')

# %%
states = df[df["state"] != "United States"]

# %% [markdown]
# ## National Averages

# %%
# Get the US row
us = df[df["state"] == "United States"]

print("National Averages (Tuition & Fees only):")
print("Public 4-year in-state 2021-22:  $", us["pub4_instate_tf_2122"].values[0])
print("Public 4-year in-state 2022-23:  $", us["pub4_instate_tf_2223"].values[0])
print("Private 4-year 2021-22:          $", us["priv4_tf_2122"].values[0])
print("Private 4-year 2022-23:          $", us["priv4_tf_2223"].values[0])
print("Public 2-year in-state 2021-22:  $", us["pub2_instate_tf_2122"].values[0])
print("Public 2-year in-state 2022-23:  $", us["pub2_instate_tf_2223"].values[0])
# Out:
# National Averages (Tuition & Fees only):
# Public 4-year in-state 2021-22:  $ 9596
# Public 4-year in-state 2022-23:  $ 9750
# Private 4-year 2021-22:          $ 34051.0
# Private 4-year 2022-23:          $ 35248.0
# Public 2-year in-state 2021-22:  $ 3563.0
# Public 2-year in-state 2022-23:  $ 3598.0

# %% [markdown]
# ## Average Tuition Across All States

# %%
print("Average tuition & fees across all states (2022-23):")
print("Public 4-year in-state: $", round(states["pub4_instate_tf_2223"].mean(), 2))
print("Private 4-year:         $", round(states["priv4_tf_2223"].mean(), 2))
print("Public 2-year in-state: $", round(states["pub2_instate_tf_2223"].mean(), 2))
# Out:
# Average tuition & fees across all states (2022-23):
# Public 4-year in-state: $ 10213.75
# Private 4-year:         $ 31544.43
# Public 2-year in-state: $ 4327.38

# %% [markdown]
# ## Tuition By State Ranked

# %%
# Public 4-year, most to least expensive
pub4_by_state = states[["state", "pub4_instate_tf_2223"]].sort_values("pub4_instate_tf_2223", ascending=False)
print("Public 4-year in-state tuition by state (2022-23):")
print(pub4_by_state.to_string(index=False))

# Private 4-year, most to least expensive
priv4_by_state = states[["state", "priv4_tf_2223"]].sort_values("priv4_tf_2223", ascending=False)
print("\nPrivate 4-year tuition by state (2022-23):")
print(priv4_by_state.to_string(index=False))

# Public 2-year, most to least expensive
pub2_by_state = states[["state", "pub2_instate_tf_2223"]].sort_values("pub2_instate_tf_2223", ascending=False)
print("\nPublic 2-year in-state tuition by state (2022-23):")
print(pub2_by_state.to_string(index=False))
# Out:
# Public 4-year in-state tuition by state (2022-23):
#                state  pub4_instate_tf_2223
#              Vermont                 17600
#        New Hampshire                 17019
#         Pennsylvania                 16217
#          Connecticut                 15763
#           New Jersey                 15265
#             Illinois                 14921
#             Virginia                 14825
#         Rhode Island                 14744
#             Michigan                 14718
#        Massachusetts                 14345
#            Minnesota                 12873
#       South Carolina                 12604
#               Oregon                 12424
#             Delaware                 11922
#              Arizona                 11768
#             Kentucky                 11299
#              Alabama                 11081
#                 Ohio                 10922
#                Maine                 10813
#               Hawaii                 10484
# ...

# %% [markdown]
# ## Public vs. Private Comparison

# %%
avg_public = round(states["pub4_instate_tf_2223"].mean(), 2)
avg_private = round(states["priv4_tf_2223"].mean(), 2)
avg_community = round(states["pub2_instate_tf_2223"].mean(), 2)

difference = round(avg_private - avg_public, 2)

print("Public vs Private Comparison (2022-23 average across states):")
print("Public 4-year in-state: $", avg_public)
print("Private 4-year:         $", avg_private)
print("Public 2-year in-state: $", avg_community)
print("Private costs $", difference, "more than public 4-year on average")
# Out:
# Public vs Private Comparison (2022-23 average across states):
# Public 4-year in-state: $ 10213.75
# Private 4-year:         $ 31544.43
# Public 2-year in-state: $ 4327.38
# Private costs $ 21330.68 more than public 4-year on average

# %% [markdown]
# ## Changes from 21-22 to 22-23 for each school type

# %%
states = states.copy()

states["pub4_change"] = states["pub4_instate_tf_2223"] - states["pub4_instate_tf_2122"]
states["priv4_change"] = states["priv4_tf_2223"] - states["priv4_tf_2122"]
states["pub2_change"] = states["pub2_instate_tf_2223"] - states["pub2_instate_tf_2122"]

print("Average tuition increase from 2021-22 to 2022-23:")
print("Public 4-year in-state: $", round(states["pub4_change"].mean(), 2))
print("Private 4-year:         $", round(states["priv4_change"].mean(), 2))
print("Public 2-year in-state: $", round(states["pub2_change"].mean(), 2))

print("\nPublic 4-year change by state:")
pub4_yoy = states[["state", "pub4_instate_tf_2122", "pub4_instate_tf_2223", "pub4_change"]].sort_values("pub4_change", ascending=False)
print(pub4_yoy.to_string(index=False))

print("\nPrivate 4-year change by state:")
priv4_yoy = states[["state", "priv4_tf_2122", "priv4_tf_2223", "priv4_change"]].sort_values("priv4_change", ascending=False)
print(priv4_yoy.to_string(index=False))

print("\nPublic 2-year change by state:")
pub2_yoy = states[["state", "pub2_instate_tf_2122", "pub2_instate_tf_2223", "pub2_change"]].sort_values("pub2_change", ascending=False)
print(pub2_yoy.to_string(index=False))
# Out:
# Average tuition increase from 2021-22 to 2022-23:
# Public 4-year in-state: $ 194.98
# Private 4-year:         $ 982.22
# Public 2-year in-state: $ 70.34
#
# Public 4-year change by state:
#                state  pub4_instate_tf_2122  pub4_instate_tf_2223  pub4_change
#         Pennsylvania                 14920                 16217         1297
#          Connecticut                 14963                 15763          800
#             Michigan                 14112                 14718          606
#         Rhode Island                 14172                 14744          572
#               Oregon                 11871                 12424          553
#             Virginia                 14273                 14825          552
#            Minnesota                 12345                 12873          528
#                 Ohio                 10456                 10922          466
#                 Iowa                  9670                 10121          451
# ...

# %% [markdown]
# ## Changes in Tuition Visual

# %%
states = states.copy()
states["pub4_change"] = states["pub4_instate_tf_2223"] - states["pub4_instate_tf_2122"]
states["priv4_change"] = states["priv4_tf_2223"] - states["priv4_tf_2122"]
states["pub2_change"] = states["pub2_instate_tf_2223"] - states["pub2_instate_tf_2122"]

# Public 4-year
pub4_yoy = states[["state", "pub4_change"]].dropna().sort_values("pub4_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(pub4_yoy["state"], pub4_yoy["pub4_change"])
plt.title("Public 4-Year In-State Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# Private 4-year
priv4_yoy = states[["state", "priv4_change"]].dropna().sort_values("priv4_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(priv4_yoy["state"], priv4_yoy["priv4_change"])
plt.title("Private 4-Year Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# Public 2-year
pub2_yoy = states[["state", "pub2_change"]].dropna().sort_values("pub2_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(pub2_yoy["state"], pub2_yoy["pub2_change"])
plt.title("Public 2-Year In-State Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Public 4-year tuition change by state VISUAL

# %%
import matplotlib.pyplot as plt

pub4_yoy = states[["state", "pub4_change"]].dropna().sort_values("pub4_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(pub4_yoy["state"], pub4_yoy["pub4_change"])
plt.title("Public 4-Year In-State Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change in Tuition & Fees ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Private 4-year tuition change by state VISUAL

# %%
priv4_yoy = states[["state", "priv4_change"]].dropna().sort_values("priv4_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(priv4_yoy["state"], priv4_yoy["priv4_change"])
plt.title("Private 4-Year Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change in Tuition & Fees ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Public 2-year tuition change by state VISUAL

# %%
pub2_yoy = states[["state", "pub2_change"]].dropna().sort_values("pub2_change", ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(pub2_yoy["state"], pub2_yoy["pub2_change"])
plt.title("Public 2-Year In-State Tuition Change by State (2021-22 to 2022-23)")
plt.xlabel("State")
plt.ylabel("Change in Tuition & Fees ($)")
plt.xticks(rotation=90)
plt.axhline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## States above and below national averges

# %%
# Averages
pub4_avg = states["pub4_instate_tf_2223"].mean()
priv4_avg = states["priv4_tf_2223"].mean()
pub2_avg = states["pub2_instate_tf_2223"].mean()

print("PUBLIC 4-YEAR AVERAGE: $", round(pub4_avg, 2))
pub4_above = states[states["pub4_instate_tf_2223"] > pub4_avg]["state"]
pub4_below = states[states["pub4_instate_tf_2223"] < pub4_avg]["state"]
print("Above average states:", list(pub4_above))
print("Below average states:", list(pub4_below))

print("\nPRIVATE 4-YEAR AVERAGE: $", round(priv4_avg, 2))
priv4_above = states[states["priv4_tf_2223"] > priv4_avg]["state"]
priv4_below = states[states["priv4_tf_2223"] < priv4_avg]["state"]
print("Above average states:", list(priv4_above))
print("Below average states:", list(priv4_below))

print("\nPUBLIC 2-YEAR AVERAGE: $", round(pub2_avg, 2))
pub2_above = states[states["pub2_instate_tf_2223"] > pub2_avg]["state"]
pub2_below = states[states["pub2_instate_tf_2223"] < pub2_avg]["state"]
print("Above average states:", list(pub2_above))
print("Below average states:", list(pub2_below))
# Out:
# PUBLIC 4-YEAR AVERAGE: $ 10213.75
# Above average states: ['Alabama', 'Arizona', 'Connecticut', 'Delaware', 'Hawaii', 'Illinois', 'Kentucky', 'Maine', 'Massachusetts', 'Michigan', 'Minnesota', 'New Hampshire', 'New Jersey', 'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Vermont', 'Virginia']
# Below average states: ['1', 'Alaska', 'Arkansas', 'California', 'Colorado', 'District of Columbia', 'Florida', 'Georgia', 'Idaho', 'Indiana', 'Iowa', 'Kansas', 'Louisiana', 'Maryland', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Oklahoma', 'South Dakota', 'Texas', 'Utah', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
#
# PRIVATE 4-YEAR AVERAGE: $ 31544.43
# ...
